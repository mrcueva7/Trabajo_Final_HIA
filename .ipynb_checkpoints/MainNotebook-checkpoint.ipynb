# %%
import pandas as pd
import sqlite3
import pygwalker as pyg

# %%
mediciones = pd.read_csv("Data/DS_Mediciones_Clima.csv", sep=";")

# %%
conn = sqlite3.connect("Base/ciudades.db")

# %%
cursor = conn.cursor()

# %%
clima = pd.read_sql("SELECT * FROM ciudades", con=conn)

# %%
mediciones
# Out:
#       CODIGO_CIUDAD             date  temperature_2m  wind_speed_10m  \
# 0               OCC   23/4/2023 7:00        10926499         3396233
# 1               NLO   23/4/2023 8:00          117765        21897945
# 2               GPS   23/4/2023 9:00          123765        50911684
# 3               GPS  23/4/2023 10:00          128765        29024127
# 4               SCY  23/4/2023 11:00          130265        43349743
# ...             ...              ...             ...             ...
# 17899           GPS    8/5/2025 2:00           95765        15379207
# 17900           GPS    8/5/2025 3:00         9176499         3438895
# 17901           GPS    8/5/2025 4:00           86265         3572898
# 17902           ETR    8/5/2025 5:00           84765        28001428
# 17903           MEC    8/5/2025 6:00        77264996        18532133
#
#        wind_speed_100m  relative_humidity_2m  weather_code  rain  \
# 0             66185193               8658815            30     0
# 1              3671294               8268405            30     0
# 2              7072878              77624985           510     1
# 3             40249224              74112206           510     1
# 4             56233797               7388791           510     2
# ...                ...                   ...           ...   ...
# 17899         34623692               8269127            20     0
# 17900          5920878               8494522            20     0
# 17901         75942082               8725382            30     0
# 17902          6114703               8814405            20     0
# 17903         45536795               8961118            20     0
#
#        pressure_msl  apparent_temperature  precipitation  cloud_cover  \
# 0             10182              10110747              0         1000
# 1             10190              11176652              0         1000
# 2             10199              11260727              1         1000
# 3             10199              12027731              1         1000
# 4             10195              11994795              2         1000
# ...             ...                   ...            ...          ...
# 17899         10196                853143              0          540
# 17900         10196               7854185              0          770
# 17901         10197               7249462              0          890
# 17902         10202               7212145              0          730
# 17903         10207               6485304              0          760
#
#        soil_temperature_0_to_7cm CODIGO_CIUDAD.1
# 0                       10676499             OCC
# 1                         113765             NLO
# 2                         124765             GPS
# 3                       13426499             GPS
# 4                       14176499             SCY
# ...                          ...             ...
# 17899                      99765             GPS
# 17900                      98265             GPS
# 17901                    9676499             GPS
# 17902                      96265             ETR
# 17903                      93265             MEC
#
# [17904 rows x 14 columns]

# %%
clima
# Out:
#     id CODIGO_CIUDAD         CIUDAD   REGION ALTURA
# 0    1           UIO          QUITO   SIERRA   2850
# 1    2           CUE         CUENCA   SIERRA   2550
# 2    3           LOH           LOJA   SIERRA   2530
# 3    4           AMB         AMBATO   SIERRA   2500
# 4    5           TEN           PUYO  ORIENTE    950
# 5    6           ZAM         ZAMORA  ORIENTE    920
# 6    7           SCY  SAN CRISTOBAL    COSTA    730
# 7    8           OCC           COCA  ORIENTE    300
# 8    9           NLO     NUEVA LOJA  ORIENTE    297
# 9   10           GPS         BALTRA    COSTA    100
# 10  11           ETR     SANTA ROSA    COSTA     10
# 11  12           MEC          MANTA    COSTA      6
# 12  13           GYE      GUAYAQUIL    COSTA      4

# %%
unificado = pd.merge(mediciones, clima, on='CODIGO_CIUDAD')

# %%
unificado
# Out:
#       CODIGO_CIUDAD             date  temperature_2m  wind_speed_10m  \
# 0               OCC   23/4/2023 7:00        10926499         3396233
# 1               NLO   23/4/2023 8:00          117765        21897945
# 2               GPS   23/4/2023 9:00          123765        50911684
# 3               GPS  23/4/2023 10:00          128765        29024127
# 4               SCY  23/4/2023 11:00          130265        43349743
# ...             ...              ...             ...             ...
# 17899           GPS    8/5/2025 2:00           95765        15379207
# 17900           GPS    8/5/2025 3:00         9176499         3438895
# 17901           GPS    8/5/2025 4:00           86265         3572898
# 17902           ETR    8/5/2025 5:00           84765        28001428
# 17903           MEC    8/5/2025 6:00        77264996        18532133
#
#        wind_speed_100m  relative_humidity_2m  weather_code  rain  \
# 0             66185193               8658815            30     0
# 1              3671294               8268405            30     0
# 2              7072878              77624985           510     1
# 3             40249224              74112206           510     1
# 4             56233797               7388791           510     2
# ...                ...                   ...           ...   ...
# 17899         34623692               8269127            20     0
# 17900          5920878               8494522            20     0
# 17901         75942082               8725382            30     0
# 17902          6114703               8814405            20     0
# 17903         45536795               8961118            20     0
#
#        pressure_msl  apparent_temperature  precipitation  cloud_cover  \
# 0             10182              10110747              0         1000
# 1             10190              11176652              0         1000
# 2             10199              11260727              1         1000
# 3             10199              12027731              1         1000
# 4             10195              11994795              2         1000
# ...             ...                   ...            ...          ...
# 17899         10196                853143              0          540
# 17900         10196               7854185              0          770
# 17901         10197               7249462              0          890
# 17902         10202               7212145              0          730
# 17903         10207               6485304              0          760
#
#        soil_temperature_0_to_7cm CODIGO_CIUDAD.1  id         CIUDAD   REGION  \
# 0                       10676499             OCC   8           COCA  ORIENTE
# 1                         113765             NLO   9     NUEVA LOJA  ORIENTE
# 2                         124765             GPS  10         BALTRA    COSTA
# 3                       13426499             GPS  10         BALTRA    COSTA
# 4                       14176499             SCY   7  SAN CRISTOBAL    COSTA
# ...                          ...             ...  ..            ...      ...
# 17899                      99765             GPS  10         BALTRA    COSTA
# 17900                      98265             GPS  10         BALTRA    COSTA
# 17901                    9676499             GPS  10         BALTRA    COSTA
# 17902                      96265             ETR  11     SANTA ROSA    COSTA
# 17903                      93265             MEC  12          MANTA    COSTA
#
#       ALTURA
# 0        300
# 1        297
# 2        100
# 3        100
# 4        730
# ...      ...
# 17899    100
# 17900    100
# 17901    100
# 17902     10
# 17903      6
#
# [17904 rows x 18 columns]

# %%
pyg.walk(unificado)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-00063586ca07e85bFR0ZI7KzpUTHQN52" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "00063586ca07e85bFR0ZI7KzpUTHQN52") {
#             var iframe = document.getElementById("gwalker-00063586ca07e85bFR0ZI7KzpUTHQN52");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
